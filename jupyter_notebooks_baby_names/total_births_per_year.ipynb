# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/baby_names_all_years.csv')

# %%
df
# Out:
#              names gender  frequency  year
# 0             Mary      F       7065  1880
# 1             Anna      F       2604  1880
# 2             Emma      F       2003  1880
# 3        Elizabeth      F       1939  1880
# 4           Minnie      F       1746  1880
# ...            ...    ...        ...   ...
# 2052776     Zyeire      M          5  2021
# 2052777       Zyel      M          5  2021
# 2052778      Zyian      M          5  2021
# 2052779      Zylar      M          5  2021
# 2052780        Zyn      M          5  2021
#
# [2052781 rows x 4 columns]

# %%
df["year"].unique()
# Out:
# array([1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890,
#        1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901,
#        1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912,
#        1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923,
#        1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934,
#        1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945,
#        1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#        1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
#       dtype=int64)

# %%
births_dict = {'year':[], 'total_births':[]}

# %%
def pars_data(year):
    file_path = (f"../data/names/yob{year}.txt")
    df = pd.read_csv(file_path, names=["names", "gender", "frequency"])
    df["year"] = year
    return df

# %%
pars_data(1990)["frequency"].sum()
# Out:
# 3951988

# %%
for year in range(1880, 2022):
    births_dict["year"].append(year)
    total = pars_data(year)["frequency"].sum()
    births_dict["total_births"].append(total)

# %%
births_dict
# Out:
# {'year': [1880,
#   1881,
#   1882,
#   1883,
#   1884,
#   1885,
#   1886,
#   1887,
#   1888,
#   1889,
#   1890,
#   1891,
#   1892,
#   1893,
#   1894,
#   1895,
#   1896,
#   1897,
#   1898,
#   1899,
#   1900,
#   1901,
#   1902,
#   1903,
#   1904,
#   1905,
#   1906,
#   1907,
#   1908,
#   1909,
#   1910,
#   1911,
#   1912,
#   1913,
#   1914,
#   1915,
#   1916,
#   1917,
#   1918,
#   1919,
#   1920,
#   1921,
#   1922,
#   1923,
#   1924,
#   1925,
#   1926,
#   1927,
#   1928,
#   1929,
#   1930,
#   1931,
#   1932,
#   1933,
#   1934,
#   1935,
#   1936,
#   1937,
#   1938,
#   1939,
#   1940,
#   1941,
#   1942,
#   1943,
#   1944,
#   1945,
#   1946,
#   1947,
#   1948,
#   1949,
#   1950,
#   1951,
#   1952,
#   1953,
#   1954,
#   1955,
#   1956,
#   1957,
#   1958,
#   1959,
#   1960,
#   1961,
#   1962,
#   1963,
#   1964,
#   1965,
#   1966,
#   1967,
#   1968,
#   1969,
#   1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
# ...

# %%
new_df = pd.DataFrame(births_dict)
new_df
# Out:
#      year  total_births
# 0    1880        201484
# 1    1881        192690
# 2    1882        221533
# 3    1883        216944
# 4    1884        243461
# ..    ...           ...
# 137  2017       3570234
# 138  2018       3508655
# 139  2019       3461444
# 140  2020       3327419
# 141  2021       3361375
#
# [142 rows x 2 columns]

# %%
yearly_births = new_df
yearly_births
# Out:
#      year  total_births
# 0    1880        201484
# 1    1881        192690
# 2    1882        221533
# 3    1883        216944
# 4    1884        243461
# ..    ...           ...
# 137  2017       3570234
# 138  2018       3508655
# 139  2019       3461444
# 140  2020       3327419
# 141  2021       3361375
#
# [142 rows x 2 columns]

# %%
x = yearly_births["year"]
y = yearly_births["total_births"]


plt.style.use("ggplot")
plt.figure(figsize=(7.5, 5.8))
plt.bar(x, y, label="Total births/year", color="navy")


plt.title("Total births/year")


plt.xlabel("year")
plt.ylabel("total_births")

plt.legend();
